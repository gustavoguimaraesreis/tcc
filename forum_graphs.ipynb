# %%
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# Um mes depois
sns.set_theme(style="whitegrid")

tweets = pd.read_json("afterDate-DeepAnswersEnUS.json")

for column in tweets.columns[8:9]:
    tweets[column] = tweets[column].str.slice(start=0, stop=10)
    tweets[column] = pd.to_datetime(tweets[column], format="%Y-%m-%d")

tweets['Month'] = tweets['dataCreated'].dt.month

f, ax = plt.subplots(figsize=(15, 10))

sns.countplot(x= tweets['Month'])

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.05, p.get_height()+20), fontsize = 12)

# %%
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# Um mes depois
sns.set_theme(style="whitegrid")

tweets = pd.read_json("afterDate-DeepAnswersEnUS.json")
# dataList = []

# for column in tweets.columns[8:9]:
#     tweets[column] = tweets[column].str.slice(start=0, stop=10)
#     tweets[column] = pd.to_datetime(tweets[column], format="%Y-%m-%d")
#     dataList.append(tweets[column])

# for data in dataList:
#     print(data)

#importante: print(tweets[column][1].get("id"))
print(tweets.info)
# print(tweets.dtypes)
# print(tweets.values)

# for column in tweets.columns[10:11]:
#     print()
    # print(type(tweets[column]))
    #print(tweets[column].get("dataCreated"))

# print(dataList)
# print(forum_post["answers"])
# for value in forum_post["answers"]:
#     for x in value:
#         if(type(x) == "NoneType"):
#             continue
#         print(x)

# for values in forum_post[10:11]:
#     print(values)
# Syntax of Series.iteritems
# Series.iteritems()

    # print(type(forum_post[column]))




# forum_post['Month'] = forum_post['dataCreated'].dt.month

# f, ax = plt.subplots(figsize=(15, 10))

# sns.countplot(x= forum_post['Month'])

# for p in ax.patches:
#     ax.annotate(int(p.get_height()), (p.get_x()+0.05, p.get_height()+20), fontsize = 12)
# Out:
# <bound method DataFrame.info of     id                                              title
# 0    9                              Guys, is this a scam?  \
# 1   10                              Buy real money legit?
# 2   12                             Is this website legit?
# 3   13                      upload to the covid-19 system
# 4   14  http://olknlw3zybrtfonomv72prkx3zfjxq5vihpw7mz...
# 5   15                                     My cyock hurtz
# 6   17  I search real site for undetected Counterfeit ...
# 7   28  Did you ever took service of hacker from deep ...
# 8   29    how to install apk automatically after download
# 9   31                                     Hack Instagram
# 10  32                      is the vendor darkmart legit?
# 11  33                 I wanna see Plane or Train Crashes
# 12  35       Me bank account hack karna no help sakta he?
# 13  36      how to track a phone number location for free
# 14  39  please ! help [ps3 ofw, savegame changes] modi...
# ...

# %%
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt


# DataFrame -> Series -> List
tweets = pd.read_json("afterDate-DeepAnswersEnUS.json")
# for row in tweets.itertuples(index=False, name="Forum_post"):
#     print(row)
# print(tweets.dtypes)

# print(type(tweets[column][0])) Type: list
i = 0
for column in tweets.columns[10:]:
    print(tweets[column].get(key=i))
    i = i +1
    # print(tweets[column]) #type: Pandas:Series


# for column in tweets.columns[10:]:
#    for index, value in tweets[column].items():
#       print(f"Index : {index}, Value : {value}")
# Out:
# [{'id': 10, 'questionId': 9, 'answerContent': 'Yes bro, the are scammers, also they appear on the most of lists of scam sites.', 'votes': '0', 'type': 'answered', 'author': '', 'dataCreated': '2022-04-02T16:51:43Z', 'points': '', 'comments': [{'id': 17, 'answerId': 10, 'comment': 'Legit Site', 'type': 'commented', 'author': '', 'dataCreated': '2022-04-22T07:16:46Z'}]}]
