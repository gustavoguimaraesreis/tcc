# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 

# Tres meses antes do ocorrido:
sns.set_theme(style="whitegrid")
tweets = pd.read_json("tweets/facebook/tres-meses/facebook data leak_2021-01-02_2021-04-02.json",
                     lines=True, nrows=94, convert_dates=False)


tweets["Date"] = pd.to_datetime(tweets.Date, format="%d/%m/%Y")
tweets["Month"] = tweets["Date"].dt.month


f, ax = plt.subplots(figsize=(15, 10))

sns.countplot(x= tweets["Month"])
# sns.histplot(x=tweets["Month"])
ax.set_xlabel("Meses", size = 12 ) 
ax.set_ylabel("Quantidade de Tweets" , size = 12 )
ax.set_xticklabels(["Janeiro", "Fevereiro", "Março", "Abril"])
ax.set_xticks(minor=False)
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.05, p.get_height()+20), fontsize = 12) 


# chart = sns.displot(x= tweets["Month"], kind="kde")
# chart.set_xlabels("Meses")
# chart.set_ylabels("Densidade")

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 

# Tres meses depois do ocorrido:
sns.set_theme(style="whitegrid")
tweets = pd.read_json("tweets-facebook/tres-meses/facebook data leak_2021-04-02_2021-07-02.json",
                     lines=True, nrows=3236, convert_dates=False)


tweets["Date"] = pd.to_datetime(tweets.Date, format="%d/%m/%Y")
tweets["Month"] = tweets["Date"].dt.month


f, ax = plt.subplots(figsize=(15, 10))

sns.countplot(x= tweets["Month"])
ax.set_xlabel("Meses", size = 12 ) 
ax.set_ylabel("Quantidade de Tweets" , size = 12 )
ax.set_xticklabels(["Abril", "Maio", "Junho", "Julho"])

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.05, p.get_height()+20), fontsize = 12)

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 

# Tres meses depois do ocorrido
sns.set_theme(style="whitegrid") 

tweets = pd.read_json("tweets/facebook/tres-meses/facebook data leak_2021-04-02_2021-07-02.json",
                     lines=True, convert_dates=False)

tweets['Date'] = pd.to_datetime(tweets.Date, format='%d/%m/%Y')

tweets['Month'] = tweets['Date'].dt.month

f, ax = plt.subplots(figsize=(15, 10))

sns.countplot(x= tweets['Month'])

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.05, p.get_height()+20), fontsize = 12)

# %%
import pandas as pd
from datetime import datetime
import seaborn as sns 
import matplotlib.pyplot as plt 

# Um mes antes
sns.set_theme(style="whitegrid") 

tweets = pd.read_json("tweets/facebook/um-mes/facebook data leak_2021-03-02_2021-04-02.json",
                     lines=True, convert_dates=False)

tweets['Date'] = pd.to_datetime(tweets.Date, format='%d/%m/%Y')

tweets['MonthDay'] = tweets['Date'].dt.day 

f, ax = plt.subplots(figsize=(15, 10))

sns.countplot(x= tweets['MonthDay'])

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.05, p.get_height()+20), fontsize = 12)

# %%
import pandas as pd
from datetime import datetime
import seaborn as sns 
import matplotlib.pyplot as plt 

# Um mes depois
sns.set_theme(style="whitegrid") 

tweets = pd.read_json("tweets/facebook/um-mes/facebook data leak_2021-04-02_2021-05-02.json",
                     lines=True, convert_dates=False)

tweets['Date'] = pd.to_datetime(tweets.Date, format='%d/%m/%Y')

tweets['MonthDay'] = tweets['Date'].dt.day 

f, ax = plt.subplots(figsize=(15, 10))

sns.countplot(x= tweets['MonthDay'])

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.05, p.get_height()+20), fontsize = 12)

# %%
import pandas as pd
from datetime import datetime
import seaborn as sns 
import matplotlib.pyplot as plt 

# Um mes depois
sns.set_theme(style="whitegrid") 

tweets = pd.read_json("tweets/facebook/janeiro.json",
                     lines=True, convert_dates=False)

tweets['Date'] = pd.to_datetime(tweets.Date, format='%d/%m/%Y')

tweets['MonthDay'] = tweets['Date'].dt.day 

f, ax = plt.subplots(figsize=(15, 10))

sns.countplot(x= tweets['MonthDay'])
ax.set_xlabel("Dias", size = 12 ) 
ax.set_ylabel("Quantidade de Tweets" , size = 12 )

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.05, p.get_height()+20), fontsize = 12)

# %%
import pandas as pd
from datetime import datetime
import seaborn as sns 
import matplotlib.pyplot as plt 

# Um mes depois
sns.set_theme(style="whitegrid") 

tweets = pd.read_json("tweets/facebook/abril.json",
                     lines=True, convert_dates=False)

tweets['Date'] = pd.to_datetime(tweets.Date, format='%d/%m/%Y')

tweets['MonthDay'] = tweets['Date'].dt.day 

f, ax = plt.subplots(figsize=(15, 10))

sns.countplot(x= tweets['MonthDay'])
ax.set_xlabel("Dias", size = 12 ) 
ax.set_ylabel("Quantidade de Tweets" , size = 12 )

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.05, p.get_height()+20), fontsize = 12)
